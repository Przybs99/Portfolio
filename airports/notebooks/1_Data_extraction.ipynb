# %% [markdown]
#  # Notebook description
#
# In this notebook the data is downloaded from API.
#
# For the purpose of this project these are the endpoints which are needed:
#  - `airport` - airports data,
#  - `weather` - information about the weather at given airport on given day,
#  - `aircraft` - aircraft data
#  - `flights` - infromation about departures from given airport at given date
#
# To retreive data from airport endpoint there is 'airport_id' parameter needed which is taken from airports.csv file.

# %% [markdown]
# --------------------------------------------------------------------------------------

# %% [markdown]
#  Libraries import and loading enviroment variables

# %%
import requests
import json
import pandas as pd
import time
from dotenv import load_dotenv
from os import environ

# %%
dotenv_path = '../.env'
load_dotenv(dotenv_path)
# Out:
# True

# %% [markdown]
#  API parameters

# %%
apikey = environ.get('API_KEY')
api = environ.get('API_URL')

# %% [markdown]
#  Uploading airports.csv file

# %%
airports = pd.read_csv(r'..\data\airports.csv')
airports.describe()
# Out:
#        origin_airport_id
# count         364.000000
# mean        12730.376374
# std          1647.879998
# min         10135.000000
# 25%         11272.250000
# 50%         12515.000000
# 75%         14160.750000
# max         16869.000000

# %% [markdown]
#  # Downloading `Airport` endpoint

# %%
data = []
for airportId in airports['origin_airport_id']:
    res = requests.get(f'{api}/airport/{airportId}', headers = {'Authorization': apikey})
    if res.status_code == 200:
        data.append(res.json())
        time.sleep(1)
    else:
        continue

# %% [markdown]
#  Saving data to dataframe

# %%
airport_df = pd.DataFrame.from_records(data)
airport_df.head()
# Out:
#    ORIGIN_AIRPORT_ID            DISPLAY_AIRPORT_NAME ORIGIN_CITY_NAME  \
# 0              11638             Fresno Air Terminal       Fresno, CA
# 1              13342          General Mitchell Field    Milwaukee, WI
# 2              13244           Memphis International      Memphis, TN
# 3              15096  Syracuse Hancock International     Syracuse, NY
# 4              10397               Atlanta Municipal      Atlanta, GA
#
#                                                 NAME
# 0               FRESNO YOSEMITE INTERNATIONAL, CA US
# 1                  MILWAUKEE MITCHELL AIRPORT, WI US
# 2               MEMPHIS INTERNATIONAL AIRPORT, TN US
# 3      SYRACUSE HANCOCK INTERNATIONAL AIRPORT, NY US
# 4  ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...

# %% [markdown]
#  Saving dataframe to .csv file

# %%
airport_df.to_csv(r'..\data\raw\airport_list.csv')

# %% [markdown]
#  # Downloading `Weather` endpoint

# %% [markdown]
#  Endpoints consist of data from January 2019 to April 2020 so in the next step list of months is created to iterate through them and retreive data for each month at a time

# %%
month_list = pd.date_range(start='1/2019', end='4/2020', freq='M').to_period('m')
month_list
# Out:
# PeriodIndex(['2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06',
#              '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12',
#              '2020-01', '2020-02', '2020-03'],
#             dtype='period[M]')

# %%
data = []

for month in month_list:
    res = requests.get(f'{api}/airportWeather?date={month}', headers = {'Authorization': apikey})
    print(month)
    if res.status_code == 200:
        for day in res.json():
            data.append(day)
        time.sleep(1)
    else:
        continue
# Out:
# 2019-01
# 2019-02
# 2019-03
# 2019-04
# 2019-05
# 2019-06
# 2019-07
# 2019-08
# 2019-09
# 2019-10
# 2019-11
# 2019-12
# 2020-01
# 2020-02
# 2020-03

# %% [markdown]
#  Saving data to dataframe

# %%
airport_weather_df = pd.DataFrame.from_records(data)
airport_weather_df.head()
# Out:
#    WT18      STATION                                               NAME  \
# 0  None  USW00013874  ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...
# 1  None  USW00013874  ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...
# 2  None  USW00013874  ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...
# 3  None  USW00013874  ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...
# 4  None  USW00013874  ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...
#
#          DATE   AWND  PRCP  SNOW  SNWD  TAVG  TMAX  ...  PGTM  WT10  WESD  \
# 0  2019-01-01   4.70  0.14   0.0   0.0  64.0  66.0  ...   NaN   NaN   NaN
# 1  2019-01-02   4.92  0.57   0.0   0.0  56.0  59.0  ...   NaN   NaN   NaN
# 2  2019-01-03   5.37  0.15   0.0   0.0  52.0  55.0  ...   NaN   NaN   NaN
# 3  2019-01-04  12.08  1.44   0.0   0.0  56.0  66.0  ...   NaN   NaN   NaN
# 4  2019-01-05  13.42  0.00   0.0   0.0  49.0  59.0  ...   NaN   NaN   NaN
#
#    SN32  SX32  PSUN  TSUN  TOBS  WT07  WT11
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 33 columns]

# %% [markdown]
#  Saving dataframe to .csv file

# %%
airport_weather_df.to_csv(r'..\data\raw\airport_weather.csv')

# %% [markdown]
#  # Downloading `Aircraft`

# %%
res = requests.get(f'{api}/aircraft', headers = {'Authorization': apikey})
aircraft_df = pd.DataFrame.from_records(res.json())
aircraft_df.head()
# Out:
#    MANUFACTURE_YEAR TAIL_NUM  NUMBER_OF_SEATS
# 0              1944   N54514              0.0
# 1              1945   N1651M              0.0
# 2              1953   N100CE              0.0
# 3              1953   N141FL              0.0
# 4              1953   N151FL              0.0

# %% [markdown]
# Saving dataframe to .csv file

# %%
aircraft_df.to_csv(r'..\data\raw\aircraft.csv')

# %% [markdown]
#  # Downloading `Flight`
#
#   Endpoint consists of data from January 2019 to April 2020 so in the next step list of months is created to iterate through them and retreive data for each month at a time

# %%
data = []

for airport in airports['origin_airport_id']:
    print(airport)
    for month in month_list:
        print(month)
        res = requests.get(f'{api}/flight?airportId={airport}&date={month}', headers = {'Authorization': apikey})
        if res.status_code == 200:
            for day in res.json():
                data.append(day)
            time.sleep(0.2)
        else:
            break
# Out:
# 10874
# 2019-01
# 11233
# 2019-01
# 13360
# 2019-01
# 15008
# 2019-01
# 11638
# 2019-01
# 14150
# 2019-01
# 15323
# 2019-01
# 14814
# 2019-01
# 12007
# 2019-01
# 11337
# 2019-01
# 13342
# 2019-01
# 15070
# 2019-01
# 13244
# 2019-01
# 12280
# 2019-01
# 15096
# 2019-01
# 11641
# 2019-01
# 13832
# 2019-01
# 10268
# 2019-01
# 10397
# 2019-01
# 2019-02
# 2019-03
# 2019-04
# 2019-05
# 2019-06
# 2019-07
# 2019-08
# 2019-09
# 2019-10
# 2019-11
# 2019-12
# 2020-01
# 2020-02
# 2020-03
# 15041
# 2019-01
# 10529
# 2019-01
# 12119
# 2019-01
# 11537
# 2019-01
# 11092
# 2019-01
# 10581
# 2019-01
# 13829
# 2019-01
# 15389
# 2019-01
# 10140
# 2019-01
# 12389
# 2019-01
# 11648
# 2019-01
# 15023
# 2019-01
# 11982
# 2019-01
# 10967
# 2019-01
# 11525
# 2019-01
# 10792
# 2019-01
# 14259
# 2019-01
# 11637
# 2019-01
# 10466
# 2019-01
# 10599
# 2019-01
# 10208
# 2019-01
# 15841
# 2019-01
# 14831
# 2019-01
# 2019-02
# 2019-03
# 2019-04
# 2019-05
# 2019-06
# 2019-07
# 2019-08
# 2019-09
# 2019-10
# 2019-11
# 2019-12
# 2020-01
# 2020-02
# 2020-03
# 12898
# 2019-01
# 13241
# 2019-01
# 13367
# 2019-01
# 11481
# 2019-01
# 14108
# 2019-01
# 13931
# 2019-01
# 13873
# 2019-01
# 10157
# 2019-01
# 10245
# 2019-01
# 11146
# 2019-01
# 13277
# 2019-01
# 11292
# 2019-01
# 2019-02
# 2019-03
# 2019-04
# 2019-05
# 2019-06
# 2019-07
# 2019-08
# 2019-09
# 2019-10
# 2019-11
# 2019-12
# 2020-01
# 2020-02
# 2020-03
# 11109
# 2019-01
# 13459
# 2019-01
# 11775
# 2019-01
# 16218
# 2019-01
# 14698
# 2019-01
# 14252
# 2019-01
# 13256
# 2019-01
# 13139
# 2019-01
# 12250
# 2019-01
# 11259
# 2019-01
# 2019-02
# 2019-03
# 2019-04
# 2019-05
# 2019-06
# 2019-07
# 2019-08
# 2019-09
# 2019-10
# 2019-11
# 2019-12
# 2020-01
# 2020-02
# 2020-03
# 11468
# 2019-01
# 14952
# 2019-01
# 12402
# 2019-01
# 2019-02
# 2019-03
# 2019-04
# 2019-05
# 2019-06
# 2019-07
# 2019-08
# 2019-09
# 2019-10
# 2019-11
# 2019-12
# 2020-01
# 2020-02
# 2020-03
# 14574
# 2019-01
# 11996
# 2019-01
# 11977
# 2019-01
# 11867
# 2019-01
# 11203
# 2019-01
# 11995
# 2019-01
# 15016
# 2019-01
# 10747
# 2019-01
# 14905
# 2019-01
# 12012
# 2019-01
# 14783
# 2019-01
# 14730
# 2019-01
# 10431
# 2019-01
# 10434
# 2019-01
# 16869
# 2019-01
# 10408
# 2019-01
# 12264
# 2019-01
# 11618
# 2019-01
# 2019-02
# 2019-03
# 2019-04
# 2019-05
# 2019-06
# 2019-07
# 2019-08
# 2019-09
# 2019-10
# 2019-11
# 2019-12
# 2020-01
# 2020-02
# 2020-03
#
# 2019-01
# 2019-02
# 2019-03
# 2019-04
# 2019-05
# 2019-06
# 2019-07
# 2019-08
# 2019-09
# 2019-10
# 2019-11
# 2019-12
# 2020-01
# 2020-02
# 2020-03
# 13795
# 2019-01
# 10693
# 2019-01
# 12945
# 2019-01
# 12511
# 2019-01

# %%
flight_df = pd.DataFrame.from_records(data)
flight_df.describe()
# Out:
#               MONTH  DAY_OF_MONTH   DAY_OF_WEEK  OP_CARRIER_FL_NUM  \
# count  1.386120e+06  1.386120e+06  1.386120e+06       1.386120e+06
# mean   5.673192e+00  1.570936e+01  3.903999e+00       1.774918e+03
# std    3.563204e+00  8.747288e+00  1.987461e+00       1.455752e+03
# min    1.000000e+00  1.000000e+00  1.000000e+00       1.000000e+00
# 25%    2.000000e+00  8.000000e+00  2.000000e+00       6.280000e+02
# 50%    5.000000e+00  1.600000e+01  4.000000e+00       1.494000e+03
# 75%    9.000000e+00  2.300000e+01  6.000000e+00       2.380000e+03
# max    1.200000e+01  3.100000e+01  7.000000e+00       7.881000e+03
#
#        ORIGIN_AIRPORT_ID  DEST_AIRPORT_ID  CRS_DEP_TIME      DEP_TIME  \
# count       1.386120e+06     1.386120e+06  1.386120e+06  1.347712e+06
# mean        1.262720e+04     1.261858e+04  1.334447e+03  1.337156e+03
# std         1.484031e+03     1.494426e+03  4.945813e+02  5.102164e+02
# min         1.029900e+04     1.029900e+04  1.000000e+00  1.000000e+00
# 25%         1.129200e+04     1.129200e+04  9.150000e+02  9.170000e+02
# 50%         1.289200e+04     1.289200e+04  1.329000e+03  1.331000e+03
# 75%         1.393000e+04     1.393000e+04  1.739000e+03  1.749000e+03
# max         1.530400e+04     1.530400e+04  2.359000e+03  2.400000e+03
#
#        DEP_DELAY_NEW  CRS_ARR_TIME  ...  CRS_ELAPSED_TIME  \
# count   1.347711e+06  1.386120e+06  ...      1.386120e+06
# mean    1.364892e+01  1.478206e+03  ...      1.390266e+02
# std     4.469326e+01  5.296749e+02  ...      7.457335e+01
# min     0.000000e+00  1.000000e+00  ...      3.200000e+01
# 25%     0.000000e+00  1.055000e+03  ...      9.000000e+01
# 50%     0.000000e+00  1.510000e+03  ...      1.200000e+02
# 75%     6.000000e+00  1.922000e+03  ...      1.630000e+02
# max     2.579000e+03  2.400000e+03  ...      7.270000e+02
#
#        ACTUAL_ELAPSED_TIME      DISTANCE  DISTANCE_GROUP          YEAR  \
# count         1.344638e+06  1.386120e+06    1.386120e+06  1.386120e+06
# mean          1.335066e+02  7.515743e+02    3.420200e+00  2.019195e+03
# std           7.471373e+01  5.967415e+02    2.388941e+00  3.962006e-01
# min           2.500000e+01  1.000000e+02    1.000000e+00  2.019000e+03
# 25%           8.200000e+01  3.370000e+02    2.000000e+00  2.019000e+03
# 50%           1.140000e+02  6.020000e+02    3.000000e+00  2.019000e+03
# 75%           1.590000e+02  8.880000e+02    4.000000e+00  2.019000e+03
# max           5.380000e+02  2.586000e+03    1.100000e+01  2.020000e+03
#
#        CARRIER_DELAY  WEATHER_DELAY      NAS_DELAY  SECURITY_DELAY  \
# count  257318.000000  257318.000000  257318.000000   257318.000000
# mean       18.330004       2.824019      20.688110        0.074515
# std        56.595923      26.574260      42.651874        3.527666
# min         0.000000       0.000000       0.000000        0.000000
# 25%         0.000000       0.000000       0.000000        0.000000
# 50%         0.000000       0.000000       6.000000        0.000000
# 75%        16.000000       0.000000      24.000000        0.000000
# max      2560.000000    1239.000000    1567.000000     1078.000000
#
#        LATE_AIRCRAFT_DELAY
# count        257318.000000
# mean             25.693189
# std              51.710956
# min               0.000000
# 25%               0.000000
# 50%               0.000000
# 75%              31.000000
# max            1438.000000
#
# [8 rows x 23 columns]

# %% [markdown]
# Saving dataframe to .csv file

# %%
flight_df.to_csv(r'..\data\raw\flight.csv')
